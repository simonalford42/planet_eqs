# %%
import pickle
import sr

# %%
version = 11003
results_path = f'sr_results/{version}.pkl'

# %%
reg = pickle.load(open(results_path, 'rb'))

# %%
config = {
    'version': 24880,
    'target': 'f2',
    'n': 10,
    'sr_residual': False,
}

X, y, variable_names = sr.load_inputs_and_targets(config)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 8
#       1 config = {
#       2     'version': 24880,
#       3     'target': 'f2',
#       4     'n': 10,
#       5     'sr_residual': False,
#       6 }
# ----> 8 X, y, variable_names = sr.load_inputs_and_targets(config)
#
# File ~/code/bnn_chaos_model/sr.py:81, in load_inputs_and_targets(config)
#      80 def load_inputs_and_targets(config):
# ---> 81     model = spock_reg_model.load(version=config['version'])
#      82     model.make_dataloaders()
#      83     model.eval()
#
# File ~/code/bnn_chaos_model/spock_reg_model.py:32, in load(version, seed)
#      30 f = path + '/version=0-v0.ckpt'
#      31 if os.path.exists(f):
# ---> 32     return VarModel.load_from_checkpoint(f)
#      33 f = path + '/version=0.ckpt'
#      34 if os.path.exists(f):
#
# ...
